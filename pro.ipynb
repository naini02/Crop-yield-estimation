# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/_crop+yield+prediction_data_crop_yield.csv')
df.head()
# Out:
#            Crop  Precipitation (mm day-1)  \
# 0  Cocoa, beans                   2248.92
# 1  Cocoa, beans                   1938.42
# 2  Cocoa, beans                   2301.54
# 3  Cocoa, beans                   2592.35
# 4  Cocoa, beans                   2344.72
#
#    Specific Humidity at 2 Meters (g/kg)  Relative Humidity at 2 Meters (%)  \
# 0                                 17.72                              83.40
# 1                                 17.54                              82.11
# 2                                 17.81                              82.79
# 3                                 17.61                              85.07
# 4                                 17.61                              84.12
#
#    Temperature at 2 Meters (C)  Yield
# 0                        26.01  11560
# 1                        26.11  11253
# 2                        26.24   9456
# 3                        25.56   9321
# 4                        25.76   8800

# %%
df.shape
# Out:
# (156, 6)

# %%
df.isnull().sum()
# Out:
# Crop                                    0
# Precipitation (mm day-1)                0
# Specific Humidity at 2 Meters (g/kg)    0
# Relative Humidity at 2 Meters (%)       0
# Temperature at 2 Meters (C)             0
# Yield                                   0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of                 Crop  Precipitation (mm day-1)  \
# 0       Cocoa, beans                   2248.92
# 1       Cocoa, beans                   1938.42
# 2       Cocoa, beans                   2301.54
# 3       Cocoa, beans                   2592.35
# 4       Cocoa, beans                   2344.72
# ..               ...                       ...
# 151  Rubber, natural                   2308.51
# 152  Rubber, natural                   2410.13
# 153  Rubber, natural                   2967.41
# 154  Rubber, natural                   2333.46
# 155  Rubber, natural                   2109.34
#
#      Specific Humidity at 2 Meters (g/kg)  Relative Humidity at 2 Meters (%)  \
# 0                                   17.72                              83.40
# 1                                   17.54                              82.11
# 2                                   17.81                              82.79
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Precipitation (mm day-1)  Specific Humidity at 2 Meters (g/kg)  \
# count                156.000000                            156.000000
# mean                2486.498974                             18.203077
# std                  289.457914                              0.293923
# min                 1934.620000                             17.540000
# 25%                 2302.990000                             18.030000
# 50%                 2424.550000                             18.270000
# 75%                 2718.080000                             18.400000
# max                 3085.790000                             18.700000
#
#        Relative Humidity at 2 Meters (%)  Temperature at 2 Meters (C)  \
# count                         156.000000                    156.00000
# mean                           84.737692                     26.18359
# std                             0.996226                      0.26105
# ...

# %%
plt.figure(figsize=(10, 20))
sns.countplot(y=df['Crop'])
# Out:
# <Axes: xlabel='count', ylabel='Crop'>

# %%
len(df['Crop'].unique())
# Out:
# 4

# %%
df.head()
# Out:
#            Crop  Precipitation (mm day-1)  \
# 0  Cocoa, beans                   2248.92
# 1  Cocoa, beans                   1938.42
# 2  Cocoa, beans                   2301.54
# 3  Cocoa, beans                   2592.35
# 4  Cocoa, beans                   2344.72
#
#    Specific Humidity at 2 Meters (g/kg)  Relative Humidity at 2 Meters (%)  \
# 0                                 17.72                              83.40
# 1                                 17.54                              82.11
# 2                                 17.81                              82.79
# 3                                 17.61                              85.07
# 4                                 17.61                              84.12
#
#    Temperature at 2 Meters (C)  Yield
# 0                        26.01  11560
# 1                        26.11  11253
# 2                        26.24   9456
# 3                        25.56   9321
# 4                        25.76   8800

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.distplot(df['Precipitation (mm day-1)'],color="red",bins = 15,hist_kws={'alpha':0.5})
plt.title('Precipitation (mm day-1)')
# Out:
# <ipython-input-15-6e931480ff1a>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Precipitation (mm day-1)'],color="red",bins = 15,hist_kws={'alpha':0.5})
# Text(0.5, 1.0, 'Precipitation (mm day-1)')

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.distplot(df['Relative Humidity at 2 Meters (%)'],color="blue",bins = 15,hist_kws={'alpha':0.5})
plt.title('Relative Humidity at 2 Meters (%)')
# Out:
# <ipython-input-16-28c3dc0ce875>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Relative Humidity at 2 Meters (%)'],color="blue",bins = 15,hist_kws={'alpha':0.5})
# Text(0.5, 1.0, 'Relative Humidity at 2 Meters (%)')

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.distplot(df['Yield'],color="magenta",bins = 15,hist_kws={'alpha':0.5})
plt.title('Yield')
# Out:
# <ipython-input-17-45c6e36f36b8>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Yield'],color="magenta",bins = 15,hist_kws={'alpha':0.5})
# Text(0.5, 1.0, 'Yield')

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.distplot(df['Temperature at 2 Meters (C)'],color="purple",bins = 15,hist_kws={'alpha':0.5})
plt.title('Temperature at 2 Meters (C)	')
# Out:
# <ipython-input-18-88df1a578fc2>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Temperature at 2 Meters (C)'],color="purple",bins = 15,hist_kws={'alpha':0.5})
# Text(0.5, 1.0, 'Temperature at 2 Meters (C)\t')
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.distplot(df['Specific Humidity at 2 Meters (g/kg)'],color="green",bins = 15,hist_kws={'alpha':0.5})
plt.title('Specific Humidity at 2 Meters (g/kg)')
# Out:
# <ipython-input-19-5904af2fe48f>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Specific Humidity at 2 Meters (g/kg)'],color="green",bins = 15,hist_kws={'alpha':0.5})
# Text(0.5, 1.0, 'Specific Humidity at 2 Meters (g/kg)')

# %%
numerical_columns = ['Relative Humidity at 2 Meters (%)', 'Yield', 'Temperature at 2 Meters (C)', 'Specific Humidity at 2 Meters (g/kg)']
numerical_df = df[numerical_columns]
corr_matrix = numerical_df.corr()

# Set the figure size
plt.figure(figsize=(12, 10))

# Create a heatmap with annotations for better readability
sns.heatmap(corr_matrix, annot=True, cmap='viridis', linewidths=0.5)

# Set labels and title for the heatmap
plt.xlabel('Features')
plt.ylabel('Features')
plt.title('Correlation of All the Features', fontsize=15, color='red')

# Display the plot
plt.show()

# %%
features = df[['Crop','Precipitation (mm day-1)','Specific Humidity at 2 Meters (g/kg)','Temperature at 2 Meters (C)', 'Relative Humidity at 2 Meters (%)']]
target =df['Yield']

# %%
features.head()
# Out:
#            Crop  Precipitation (mm day-1)  \
# 0  Cocoa, beans                   2248.92
# 1  Cocoa, beans                   1938.42
# 2  Cocoa, beans                   2301.54
# 3  Cocoa, beans                   2592.35
# 4  Cocoa, beans                   2344.72
#
#    Specific Humidity at 2 Meters (g/kg)  Temperature at 2 Meters (C)  \
# 0                                 17.72                        26.01
# 1                                 17.54                        26.11
# 2                                 17.81                        26.24
# 3                                 17.61                        25.56
# 4                                 17.61                        25.76
#
#    Relative Humidity at 2 Meters (%)
# 0                              83.40
# 1                              82.11
# 2                              82.79
# 3                              85.07
# 4                              84.12

# %%
target.head()
# Out:
# 0    11560
# 1    11253
# 2     9456
# 3     9321
# 4     8800
# Name: Yield, dtype: int64

# %%
# Split data into training and testing sets (80% train, 20% test)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((124, 5), (32, 5))

# %%
X_train
# Out:
#                 Crop  Precipitation (mm day-1)  \
# 56    Oil palm fruit                   2362.80
# 138  Rubber, natural                   2302.99
# 123  Rubber, natural                   2326.09
# 128  Rubber, natural                   2249.70
# 127  Rubber, natural                   2217.12
# ..               ...                       ...
# 71    Oil palm fruit                   2607.96
# 106      Rice, paddy                   2922.18
# 14      Cocoa, beans                   2686.20
# 92       Rice, paddy                   2686.20
# 102      Rice, paddy                   2363.63
#
#      Specific Humidity at 2 Meters (g/kg)  Temperature at 2 Meters (C)  \
# 56                                  18.70                        26.79
# 138                                 18.22                        26.25
# 123                                 18.09                        26.11
# 128                                 18.01                        26.11
# ...

# %%
X_test
# Out:
#                 Crop  Precipitation (mm day-1)  \
# 96       Rice, paddy                   2792.95
# 69    Oil palm fruit                   2938.29
# 82       Rice, paddy                   2344.72
# 76    Oil palm fruit                   2333.46
# 114      Rice, paddy                   2967.41
# 29      Cocoa, beans                   2546.33
# 94       Rice, paddy                   1999.53
# 132  Rubber, natural                   2414.79
# 93       Rice, paddy                   2414.79
# 139  Rubber, natural                   2692.34
# 19      Cocoa, beans                   2751.24
# 90       Rice, paddy                   2530.96
# 15      Cocoa, beans                   2414.79
# 125  Rubber, natural                   2061.61
# 24      Cocoa, beans                   2363.63
# 30      Cocoa, beans                   2938.29
# 119  Rubber, natural                   2301.54
# 101      Rice, paddy                   2424.55
# 152  Rubber, natural                   2410.13
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
# Define categorical and numerical features
categorical_features = ['Crop']
numerical_features = ['Precipitation (mm day-1)','Specific Humidity at 2 Meters (g/kg)','Relative Humidity at 2 Meters (%)', 'Temperature at 2 Meters (C)']

# Create a ColumnTransformer to handle categorical features with OneHotEncoding
preprocessor = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', numerical_features), # Passthrough numerical features
        ('cat', OneHotEncoder(sparse_output=False, handle_unknown='ignore'), categorical_features) # One-hot encode categorical features
    ])

# %%
# Create instances of OneHotEncoder and StandardScaler
ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore') # Assign OneHotEncoder object to 'ohe'
scaler = StandardScaler() # Assign StandardScaler object to 'scaler' if you intend to scale numerical features

# %%
preprocessor = ColumnTransformer(
    [
        ('ohe', ohe, ['Crop']),
        ('scaler', scaler, ['Precipitation (mm day-1)','Specific Humidity at 2 Meters (g/kg)','Relative Humidity at 2 Meters (%)','Temperature at 2 Meters (C)']) # Removed the tab character from 'Temperature at 2 Meters (C)'
    ]
)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('ohe',
#                                  OneHotEncoder(handle_unknown='ignore',
#                                                sparse_output=False),
#                                  ['Crop']),
#                                 ('scaler', StandardScaler(),
#                                  ['Precipitation (mm day-1)',
#                                   'Specific Humidity at 2 Meters (g/kg)',
#                                   'Relative Humidity at 2 Meters (%)',
#                                   'Temperature at 2 Meters (C)'])])

# %%
X_train_dummy = preprocessor.fit_transform(X_train)
X_test_dummy = preprocessor.transform(X_test)

# %%
X_train_dummy
# Out:
# array([[ 0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -4.03713411e-01,  1.63236346e+00,
#         -6.35284045e-01,  2.21266274e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -6.09950162e-01,  6.63048987e-02,
#         -1.89105949e-01,  2.06978470e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -5.30296777e-01, -3.57835961e-01,
#         -4.03799172e-02, -3.13013749e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -7.93704660e-01, -6.18845722e-01,
#         -4.27067600e-01, -3.13013749e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00, -9.06046966e-01, -5.53593281e-01,
#         -2.78341568e-01, -3.50156051e-01],
#        [ 0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  2.08929961e+00,  4.57819539e-01,
# ...

# %%
df.head()
# Out:
#            Crop  Precipitation (mm day-1)  \
# 0  Cocoa, beans                   2248.92
# 1  Cocoa, beans                   1938.42
# 2  Cocoa, beans                   2301.54
# 3  Cocoa, beans                   2592.35
# 4  Cocoa, beans                   2344.72
#
#    Specific Humidity at 2 Meters (g/kg)  Relative Humidity at 2 Meters (%)  \
# 0                                 17.72                              83.40
# 1                                 17.54                              82.11
# 2                                 17.81                              82.79
# 3                                 17.61                              85.07
# 4                                 17.61                              84.12
#
#    Temperature at 2 Meters (C)  Yield
# 0                        26.01  11560
# 1                        26.11  11253
# 2                        26.24   9456
# 3                        25.56   9321
# 4                        25.76   8800

# %%
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
models = {
    'Linear Regression': LinearRegression(),
    'Random Forest Regressor': RandomForestRegressor(n_estimators=100, random_state=42),
    'Decision Tree Regressor': DecisionTreeRegressor(random_state=42),
    'Gradient Boosting Regressor': GradientBoostingRegressor(random_state=42)
}

# Train and evaluate each model
for name, model in models.items():
    print(f'\nRunning {name}...')

    # Train the model
    model.fit(X_train_dummy, y_train)

    # Make predictions
    y_pred = model.predict(X_test_dummy)

    # Calculate performance metrics
    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    # Print the results
    print(f'\n{name} Performance:')
    print(f'MAE: {mae}')
    print(f'RMSE: {rmse}')
    print(f'R² Score: {r2}')
# Out:
# Running Linear Regression...
#
# Linear Regression Performance:
# MAE: 3132.7963836399795
# RMSE: 4394.1658189971795
# R² Score: 0.9950222133854733
#
# Running Random Forest Regressor...
#
# Random Forest Regressor Performance:
# MAE: 2699.0140625000013
# RMSE: 4656.370275704633
# R² Score: 0.9944104298760765
#
# Running Decision Tree Regressor...
#
# Decision Tree Regressor Performance:
# MAE: 3404.4375
# RMSE: 5612.092629982153
# R² Score: 0.9918804295604927
#
# Running Gradient Boosting Regressor...
#
# Gradient Boosting Regressor Performance:
# MAE: 3080.0475942631756
# RMSE: 6073.545722113928
# R² Score: 0.9904902740210173

# %%
Rf=RandomForestRegressor(n_estimators=100, random_state=42)
Rf.fit(X_train_dummy, y_train)
Rf.predict(X_test_dummy)
# Out:
# array([ 30058.43, 177023.94,  26599.61, 184210.49,  35085.77,   8597.47,
#         30006.42,   6450.76,  28951.04,   7801.8 ,   8835.72,  28222.84,
#          7229.42,   9200.6 ,   8603.88,   8400.42,   9432.26,  30719.93,
#          7914.84,  27698.97,  31236.1 ,   9642.53,   7266.61,   8607.89,
#          8700.07,  31279.78, 184677.84, 180372.89, 163151.84,  29883.03,
#        162395.3 ,   7123.8 ])

# %%
def prediction(Crop, Precipitation_mm_day_1, Specific_Humidity_at_2_Meters_g_kg, Temperature_at_2_Meters_C, Relative_Humidity_at_2_Meters_percent):
    # Create a DataFrame for the input features with the correct column names
    features = pd.DataFrame({
        'Crop': [Crop],
        'Precipitation (mm day-1)': [Precipitation_mm_day_1],
        'Specific Humidity at 2 Meters (g/kg)': [Specific_Humidity_at_2_Meters_g_kg],
        'Temperature at 2 Meters (C)': [Temperature_at_2_Meters_C],
        'Relative Humidity at 2 Meters (%)': [Relative_Humidity_at_2_Meters_percent],
        'Crop_Encoded': [Crop_Encoded]
        # Add any other missing columns that preprocessor expects, if applicable, like:'ExtraColumn': [SomeValue]
    })

    # Transform the features using the preprocessor
    transformed_features = preprocessor.transform(features)

    # Make the prediction
    predicted_yield = Rf.predict(transformed_features).reshape(1, -1)

    return predicted_yield[0]

# Your remaining code...

# Values for prediction
Crop = 'Cocoa,beans'
Precipitation_mm_day_1 = 2248.92
Specific_Humidity_at_2_Meters_g_kg = 17.72
Temperature_at_2_Meters_C = 26.02
Relative_Humidity_at_2_Meters_percent = 83.40
Crop_Encoded = 0

# Call the prediction function and assign the result to 'result'
result = prediction(Crop, Precipitation_mm_day_1, Specific_Humidity_at_2_Meters_g_kg, Temperature_at_2_Meters_C, Relative_Humidity_at_2_Meters_percent)

# Print the result after it's assigned.
print(f'Predicted Yield: {result}')
# Out:
# Predicted Yield: [10010.15]

# %%
import pickle
pickle.dump(Rf, open('model.pkl', 'wb'))
pickle.dump(preprocessor, open('preprocessor.pkl', 'wb'))
